# %%
# encoding : utf-8

import csv
import simplejson as json
from nltk import FreqDist
from nltk.tokenize import sent_tokenize, word_tokenize, RegexpTokenizer
from nltk.corpus import stopwords
from nltk.stem import PorterStemmer
from collections import OrderedDict, defaultdict

import pygal


filePath = ['../Data','../DataCleaned']
inputFileName = ['goodEatsMetadata.csv', 'goodEatsData.csv']
outputFileName = ['testNetwork.json']

# File Handlers / File Pointers
readMetadata = csv.DictReader(open('/'.join([filePath[0], inputFileName[0]]), 'r'), delimiter=',')
readData = csv.reader(open('/'.join([filePath[0], inputFileName[1]]), 'r', encoding='utf-8'), delimiter=',')

tokenized_word_set = defaultdict()
tokenizer = RegexpTokenizer(r'\w+')
stop_words = set(stopwords.words('english'))

personal_stopwords = set(('well', 'scene', 'know', 'got', 'okay', 'like', 'let', 'going', 'get', 'kind', 'really', 'way', 'lot', 'could', 'around'))
# 'one', 'two', 'three', 'four', 'five', 'six', 'seven', 'eight', 'nine', 'ten', 'zero',

# print(stop_words)
# print(personal_stopwords)

tokenized_and_stopped_wordlist = []
for data in readData:
	for word in tokenizer.tokenize(data[1]):
		if word.lower() not in stop_words and word.lower() not in personal_stopwords and len(word) > 2:
			tokenized_and_stopped_wordlist.append(word.lower())
			# counts word frequency manually
			# if word.lower() in tokenized_word_set:
			# 	tokenized_word_set[word.lower()] += 1
			# else :
			# 	tokenized_word_set[word.lower()] = 1


fdist = FreqDist(tokenized_and_stopped_wordlist)
linechart = pygal.Bar()
for token, count in fdist.most_common(25):
	linechart.add(token, count)

linechart.render(is_unicode=True)
# Out:
# '<?xml version=\'1.0\' encoding=\'utf-8\'?>\n<svg xmlns:xlink="http://www.w3.org/1999/xlink" class="pygal-chart" id="chart-70080035-9d01-450b-bd7f-dce3cc590251" viewBox="0 0 800 600" xmlns="http://www.w3.org/2000/svg"><!--Generated with pygal 2.2.3 (etree) ©Kozea 2012-2016 on 2016-08-12--><!--http://pygal.org--><!--http://github.com/Kozea/pygal--><defs><style type="text/css">#chart-70080035-9d01-450b-bd7f-dce3cc590251{-webkit-user-select:none;-webkit-font-smoothing:antialiased;font-family:Consolas,"Liberation Mono",Menlo,Courier,monospace}#chart-70080035-9d01-450b-bd7f-dce3cc590251 .title{font-family:Consolas,"Liberation Mono",Menlo,Courier,monospace;font-size:16px}#chart-70080035-9d01-450b-bd7f-dce3cc590251 .legends .legend text{font-family:Consolas,"Liberation Mono",Menlo,Courier,monospace;font-size:14px}#chart-70080035-9d01-450b-bd7f-dce3cc590251 .axis text{font-family:Consolas,"Liberation Mono",Menlo,Courier,monospace;font-size:10px}#chart-70080035-9d01-450b-bd7f-dce3cc590251 .axis text.major{font-family:Consolas,"Liberation Mono",Menlo,Courier,monospace;font-size:10px}#chart-70080035-9d01-450b-bd7f-dce3cc590251 .text-overlay text.value{font-family:Consolas,"Liberation Mono",Menlo,Courier,monospace;font-size:16px}#chart-70080035-9d01-450b-bd7f-dce3cc590251 .text-overlay text.label{font-family:Consolas,"Liberation Mono",Menlo,Courier,monospace;font-size:10px}#chart-70080035-9d01-450b-bd7f-dce3cc590251 .tooltip{font-family:Consolas,"Liberation Mono",Menlo,Courier,monospace;font-size:14px}#chart-70080035-9d01-450b-bd7f-dce3cc590251 text.no_data{font-family:Consolas,"Liberation Mono",Menlo,Courier,monospace;font-size:64px}\n#chart-70080035-9d01-450b-bd7f-dce3cc590251{background-color:rgba(249,249,249,1)}#chart-70080035-9d01-450b-bd7f-dce3cc590251 path,#chart-70080035-9d01-450b-bd7f-dce3cc590251 line,#chart-70080035-9d01-450b-bd7f-dce3cc590251 rect,#chart-70080035-9d01-450b-bd7f-dce3cc590251 circle{-webkit-transition:150ms;-moz-transition:150ms;transition:150ms}#chart-70080035-9d01-450b-bd7f-dce3cc590251 .graph &gt; .background{fill:rgba(249,249,249,1)}#chart-70080035-9d01-450b-bd7f-dce3cc590251 .plot &gt; .background{fill:rgba(255,255,255,1)}#chart-70080035-9d01-450b-bd7f-dce3cc590251 .graph{fill:rgba(0,0,0,.87)}#chart-70080035-9d01-450b-bd7f-dce3cc590251 text.no_data{fill:rgba(0,0,0,1)}#chart-70080035-9d01-450b-bd7f-dce3cc590251 .title{fill:rgba(0,0,0,1)}#chart-70080035-9d01-450b-bd7f-dce3cc590251 .legends .legend text{fill:rgba(0,0,0,.87)}#chart-70080035-9d01-450b-bd7f-dce3cc590251 .legends .legend:hover text{fill:rgba(0,0,0,1)}#chart-70080035-9d01-450b-bd7f-dce3cc590251 .axis .line{stroke:rgba(0,0,0,1)}#chart-70080035-9d01-450b-bd7f-dce3cc590251 .axis .guide.line{stroke:rgba(0,0,0,.54)}#chart-70080035-9d01-450b-bd7f-dce3cc590251 .axis .major.line{stroke:rgba(0,0,0,.87)}#chart-70080035-9d01-450b-bd7f-dce3cc590251 .axis text.major{fill:rgba(0,0,0,1)}#chart-70080035-9d01-450b-bd7f-dce3cc590251 .axis.y .guides:hover .guide.line,#chart-70080035-9d01-450b-bd7f-dce3cc590251 .line-graph .axis.x .guides:hover .guide.line,#chart-70080035-9d01-450b-bd7f-dce3cc590251 .stackedline-graph .axis.x .guides:hover .guide.line,#chart-70080035-9d01-450b-bd7f-dce3cc590251 .xy-graph .axis.x .guides:hover .guide.line{stroke:rgba(0,0,0,1)}#chart-70080035-9d01-450b-bd7f-dce3cc590251 .axis .guides:hover text{fill:rgba(0,0,0,1)}#chart-70080035-9d01-450b-bd7f-dce3cc590251 .reactive{fill-opacity:.7;stroke-opacity:.8}#chart-70080035-9d01-450b-bd7f-dce3cc590251 .ci{stroke:rgba(0,0,0,.87)}#chart-70080035-9d01-450b-bd7f-dce3cc590251 .reactive.active,#chart-70080035-9d01-450b-bd7f-dce3cc590251 .active .reactive{fill-opacity:.8;stroke-opacity:.9;stroke-width:4}#chart-70080035-9d01-450b-bd7f-dce3cc590251 .ci .reactive.active{stroke-width:1.5}#chart-70080035-9d01-450b-bd7f-dce3cc590251 .series text{fill:rgba(0,0,0,1)}#chart-70080035-9d01-450b-bd7f-dce3cc590251 .tooltip rect{fill:rgba(255,255,255,1);stroke:rgba(0,0,0,1);-webkit-transition:opacity 150ms;-moz-tran ...
